# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Colab Notebooks'  'Diploma prev exam paper'

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# 'horse detection'   Untitled0.ipynb

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/horse detection"
# Out:
# 'horse_detection.v2i.yolov8 (1).zip'

# %%
# !mv /content/runs/content/drive/MyDrive/ColabNotebooks/horsedetection/
# !mv /content/horse_training_results.zip/content/drive/MyDrive/ColabNotebooks/horsedetection/
# Out:
# mv: missing destination file operand after '/content/runs/content/drive/MyDrive/ColabNotebooks/horsedetection/'
# Try 'mv --help' for more information.
# mv: missing destination file operand after '/content/horse_training_results.zip/content/drive/MyDrive/ColabNotebooks/horsedetection/'
# Try 'mv --help' for more information.

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/horse detection/horse_detection.v2i.yolov8 (1).zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/pexels-rquiros-1848725_jpg.rf.844a895a53873b0b72d7eb9576aaa06e.jpg
#  extracting: train/images/pexels-rquiros-1848725_jpg.rf.b9a8b012e63e1d9be4c18658a6900ebc.jpg
#  extracting: train/images/pexels-septimiu-lupea-271955805-32476247_jpg.rf.18f5e0513f077c88f05b2946d752a748.jpg
#  extracting: train/images/pexels-septimiu-lupea-271955805-32476247_jpg.rf.35b48bd9752ccc6e51924701644fe9a1.jpg
#  extracting: train/images/pexels-septimiu-lupea-271955805-32476247_jpg.rf.f2f380f82cd2c7bd222d6ef8d7c04024.jpg
#  extracting: train/images/pexels-serj-2577707_jpg.rf.82246e0ba63cbf3ce5ff4d5df049a55e.jpg
#  extracting: train/images/pexels-serj-2577707_jpg.rf.96f58fdb7a645d17cc4f58e5f2711238.jpg
#  extracting: train/images/pexels-serj-2577707_jpg.rf.e7ab62f8d031a0688a7bba9bd334cf97.jpg
#  extracting: train/images/pexels-shotbyrain-3010291_jpg.rf.0ce78569deee2ca67a833f8733924e65.jpg
# ...

# %%
# !nvidia-smi
# Out:
# Wed Feb 18 16:59:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/data.yaml",
    epochs=150,
    imgsz=640,
    batch=32
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !zip -r horse_training_results.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/train_batch1.jpg (deflated 2%)
#   adding: content/runs/detect/train2/results.png (deflated 9%)
#   adding: content/runs/detect/train2/train_batch0.jpg (deflated 2%)
#   adding: content/runs/detect/train2/BoxF1_curve.png (deflated 17%)
#   adding: content/runs/detect/train2/val_batch2_labels.jpg (deflated 6%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 27%)
#   adding: content/runs/detect/train2/confusion_matrix.png (deflated 34%)
#   adding: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 36%)
#   adding: content/runs/detect/train2/train_batch16242.jpg (deflated 8%)
#   adding: content/runs/detect/train2/val_batch2_pred.jpg (deflated 6%)
#   adding: content/runs/detect/train2/args.yaml (deflated 53%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 3%)
# ...

# %%
# !unzip -r horse_detection.v2i.yolov8 (1).zip /content/drive/MyDrive/ColabNotebooks/horsedetection
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `unzip -r horse_detection.v2i.yolov8 (1).zip /content/drive/MyDrive/ColabNotebooks/horsedetection'

# %%
from ultralytics import YOLO

# load trained model
model = YOLO(r"/content/drive/MyDrive/Colab Notebooks/horse detection/horse_detection.v2i.yolov8 (1)/horse_training_results/content/runs/detect/train2/weights/best.pt")

# predict on test images
model.predict(
    source="/content/drive/MyDrive/Colab Notebooks/horse detection/horse_detection.v2i.yolov8 (1)/7658500-uhd_2160_4096_25fps.mp4",
    conf=0.4,
    show =True,
    save = True
)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/771) /content/drive/MyDrive/Colab Notebooks/horse detection/horse_detection.v2i.yolov8 (1)/7658500-uhd_2160_4096_25fps.mp4: 640x352 (no detections), 391.4ms
# video 1/1 (frame 2/771) /content/drive/MyDrive/Colab Notebooks/horse detection/horse_detection.v2i.yolov8 (1)/7658500-uhd_2160_4096_25fps.mp4: 640x352 (no detections), 379.8ms
# ...

# %%
# !zip -r horse_preict_results.zip /content/runs/detect
# Out:
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict12/ (stored 0%)
#   adding: content/runs/detect/predict12/7658500-uhd_2160_4096_25fps.avi (deflated 4%)
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/4188423-uhd_3840_2160_24fps.avi (deflated 1%)
#   adding: content/runs/detect/predict8/ (stored 0%)
#   adding: content/runs/detect/predict8/9900004-uhd_3840_2160_25fps.avi (deflated 0%)
#   adding: content/runs/detect/predict14/ (stored 0%)
#   adding: content/runs/detect/predict14/7658500-uhd_2160_4096_25fps.avi (deflated 4%)
#   adding: content/runs/detect/predict7/ (stored 0%)
#   adding: content/runs/detect/predict7/8624907-hd_1080_1920_30fps.avi (deflated 2%)
#   adding: content/runs/detect/predict4/ (stored 0%)
#   adding: content/runs/detect/predict4/5087894-uhd_2160_3840_25fps.avi (deflated 2%)
#   adding: content/runs/detect/predict9/ (stored 0%)
# ...
